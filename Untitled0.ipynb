# %% [markdown]
# <a href="https://colab.research.google.com/github/guoyj3018/python/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Drive Imports
from google.colab import drive

#Numerical imports
import numpy as np

#Other imports
import matplotlib.pyplot as plt
import time

#Avoiding versions' warnings
import os
import warnings
warnings.simplefilter("ignore")

drive.mount("/content/gdrive", force_remount = True)
os.chdir("/content/gdrive/My Drive/Colab Notebooks")
# Out:
# Mounted at /content/gdrive

# %%
def Book_Conditioning(book_raw):
    '''
        Book conditioning module
    '''

    book = book_raw
    chars = list(set(book))

    #Left almost blank on purpose for character-level Vanilla RNN
    #Any desired text-related conditioning would be coded here

    return(book, chars)

# %%
def lossFun(inputs, targets, hprev):
  '''
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  '''
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.random.rand(vocab_size,1) # encode in 1-of-k representation
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0])/len(inputs) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]



def sample(h, seed_ix, n):
  '''
  sample a sequence of integers from the model
  h is memory state, seed_ix is seed letter for first time step
  '''
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
'''
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
'''
book_name = './test_nvcccu.txt'

# 检查文件是否存在
if os.path.exists(book_name):
    print(f"文件 {book_name} 存在")
    data = open(book_name, 'r').read()
else:
    print(f"文件 {book_name} 未找到！")
    print(f"当前目录：{os.getcwd()}")
    print(f"当前目录中的文件：{os.listdir('.')}")

book_name = './quixote_reduced.txt' #Must be located at Colab Notebooks' Drive folder
book_name = './test_nvcccu.txt'
# data I/O
data = open(book_name, 'r').read() # should be simple plain text file

[data, chars] = Book_Conditioning(data)

data_size, vocab_size = len(data), len(chars)

print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# 文件 ./test_nvcccu.txt 存在
# data has 685 characters, 64 unique.

# %%
# hyperparameters
hidden_size =1000 # size of hidden layer of neurons
seq_length = 125 # number of steps to unroll the RNN for
learning_rate = 1*1e-2/hidden_size*1000
n_max = 5000 # max iterations

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.1 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.1 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.1 # hidden to output
bh = np.random.randn(hidden_size, 1)*0.1 # hidden bias
by = np.random.randn(vocab_size, 1)*0.1 # output bias

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

#Time counter
start_time = time.time()

#Cumulative variables for plotting
losses = []
times = []

while n < n_max:

  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0:
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 50 == 0:
    sample_ix = sample(hprev, inputs[10], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))
    learning_rate/=2
   #    plt.figure(1)
    #   plt.plot(losses)
     #  plt.title('Loss Evolution Along Epochs')
      # plt.xlabel('Epochs')
     #  plt.ylabel('Loss')
     #  plt.show()
  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.8 + loss * 0.2
  if n == 0: smooth_loss = loss
  if n % 10 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],
                                [dWxh, dWhh, dWhy, dbh, dby],
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter

  times.append(time.time() - start_time) #Running time so far
  losses.append(smooth_loss) #Loss evolution
# Out:
# ----
#  KP*D}slKUcy>,ts"IP9}I teLc0 UlmG=_(2\sxz/0_z{-9I!Do0"vN_b(#%ok=T(-Ap:9}T
# LDdzw.1ot-CA,a})i0K>,}"9 :<) i)}KII1#KsnE>V/_U-s0P/,LDg,-S)f\UCUCIrKx,o:PK-\*ar\\ALx"c}_;TIb,zs}g>I0;VS.2-,L!2hgpD,#x}--biU
# ,9v
# ----
# iter 0, loss: 7.379922
# iter 10, loss: 6.831321
# iter 20, loss: 6.496586
# iter 30, loss: 5.872657
# iter 40, loss: 5.444882
# ----
#  =*>typ;"rn y Ianad.;dL
# LdiiLrnrn;a;
#  1aN;nat))bi Nsa(
# i"aile( iLi1 ipecnlnii (LL1Pca.Ns)d.\1.cKfaErcrciiPra-C)ni(LCb_,ntatE )Cg;aKL;aaLGL.et E
# nCa) d/n(aa;11 ba
# /GioaeKN 1ylra f.)bKAsKv GoCrt;aeotn()
# ----
# iter 50, loss: 5.000453
# iter 60, loss: 4.632777
# iter 70, loss: 4.583493
# iter 80, loss: 4.948540
# iter 90, loss: 5.013648
# ----
#  Nvoty)uddco  nLdrr ss /nl,l(e nrtnlasgu_<cnnnn   h cw()rLn
# . C u
# ( U(i heetcn"L iieT uiC cU
# (,"ov { Ulpe(s et,__ )is l dI(eu) Tdlss  dN ids#ldkr\crw
# u SedtUoSA((ah:lLed)\niudpnu(U{nd( vs At uece!o.Kg
# ----
# iter 100, loss: 5.011939
# iter 110, loss: 5.019357
# ...

# %%
'''
    Loss evolution along time and epochs
'''

plt.figure(1)
plt.plot(losses)
plt.title('Loss Evolution Along Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

plt.figure(2)
plt.plot(times, losses)
plt.title('Loss Evolution Along Time')
plt.xlabel('Running Time (s)')
plt.ylabel('Loss')
plt.show()
